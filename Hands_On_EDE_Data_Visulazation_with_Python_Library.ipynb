# %% [markdown]
# <a href="https://colab.research.google.com/github/mhyubr/Grow-With-EDE-LAB-2023/blob/main/Hands_On_EDE_Data_Visulazation_with_Python_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Library

# %%
import seaborn as sns

# %% [markdown]
# # Dataset

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# ## distplot

# %%
sns.distplot(tips['total_bill'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['total_bill'], kde=False, bins=30)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
penguins = sns.load_dataset('penguins')

# %%
sns.displot(penguins, x="flipper_length_mm", kde=True, hue="species")

# %% [markdown]
# ## jointplot

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter', hue='sex', palette='ocean')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %% [markdown]
# # pairplot

# %%
sns.pairplot(tips, palette='coolwarm')

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %% [markdown]
# # Categorical Data Plots

# %% [markdown]
# ## barplot and countplot

# %%
sns.catplot(x='sex',y='total_bill',data=tips, kind='bar')

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# ## boxplot and violinplot

# %%
sns.boxplot(x="day", y="total_bill", data=tips, palette='rainbow')

# %%
# Can do entire dataframe with orient='h'
sns.boxplot(data=tips,palette='rainbow',orient='h')

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")

# %%
sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',palette='Set1')

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True,palette='Set1')

# %% [markdown]
# ## Matrix Plot

# %% [markdown]
# ## Heatmap

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())

# %%
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
pvflights = flights.pivot_table(values='passengers',index='month',columns='year')

sns.heatmap(pvflights)
# Out:
# Text(0.5, 15.0, '\nTahun')

# %%
sns.heatmap(pvflights,cmap='coolwarm',linecolor='white',linewidths=1)

plt.title('\nRiwayat Penerbangan\n', size=17, color='red')
plt.xlabel("\nTahun", size=12)
plt.ylabel("\nTahun", size=12)
# Out:
# Text(33.0, 0.5, '\nTahun')

# %% [markdown]
# # Regression Plot

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips, hue='smoker', palette='magma')
